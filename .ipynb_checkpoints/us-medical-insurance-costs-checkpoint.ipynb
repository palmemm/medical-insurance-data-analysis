# %% [markdown]
# # U.S. Medical Insurance Costs

# %% [markdown]
# ## In this project, medical insurance data will be analyzed and modeled to predict cost of insurance based on age. A linear regression model will be used to predict age-dependent cost variance. Analysis will be completed to determine what factor increases insurance costs the most: gender, smoking, or region.

# %% [markdown]
# ### The goal is to find a model someone could use to input their name, age, region, and smoker status to determine their approximate insurance cost

# %% [markdown]
# #### First, pull data from the file

# %%
import csv

with open("insurance.csv") as insurance_stats:
    insurance_stats_dict = csv.DictReader(insurance_stats)

    ages = []
    insurance_dict = {}
    costs = []

    index = 0
    for row in insurance_stats_dict:
        insurance_dict[index] = row
        float_age = float(row["age"])
        ages.append(float_age)
        float_costs = float(row["charges"])
        costs.append(float_costs)
        index += 1

# %% [markdown]
# ### Set up a function to pull data by category

# %%
def pull_ac_data(data_dictionary, category, index):
    category_ages = []
    category_costs = []
    cat_dictionary = {}
    i = 0
    
    for row in data_dictionary.values():
        if row[category] == index:
            cat_dictionary[i] = row
            float_age = float(row["age"])
            category_ages.append(float_age)
            float_cost = float(row["charges"])
            category_costs.append(float_cost)
        i += 1
            
    return category_ages, category_costs, cat_dictionary

# %% [markdown]
# ### Visualize Data Before Trying to find a fit

# %%
import matplotlib.pyplot as plt
plt.scatter(ages,costs)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## The data looks linear
# ### Try a Linear Regression Model to Fit Insurance Cost By Age

# %%
def calculate_linear_error(m,b,point):
    x_age = point[0]
    y_cost = point[1]
    y_calc = m * x_age + b
    error = abs(y_cost-y_calc)
    return error

# %%
def linear_reg_model_ac(ages, costs, m_range_low, m_range_high, m_step, b_range_low, b_range_high, b_step):

    possible_ms = [m for m in range(m_range_low,m_range_high,m_step)]
    possible_bs = [b for b in range(b_range_low,b_range_high,b_step)]
    age_cost_datapoints = list(zip(ages,costs))

    smallest_error = float("inf")
    best_m = 0
    best_b = 0

    for m in possible_ms:
        for b in possible_bs:
            total_error = 0
            for point in age_cost_datapoints:
                point_error = calculate_linear_error(m,b,point)
                total_error = total_error + point_error
            if total_error < smallest_error:
                smallest_error = total_error
                best_m = m                
                best_b = b

    return best_m, best_b, smallest_error


best_m,best_b,smallest_error = linear_reg_model_ac(ages, costs, 0, 1000, 5, 0, 1000, 5)
regression_model_dict = {}
regression_model_dict["age"]= {"m":best_m, "b":best_b, "smallest_error":smallest_error}
print(regression_model_dict)
# Out:
# {'age': {'m': 205, 'b': 0, 'smallest_error': 9328633.482559014}}

# %% [markdown]
# ### Test line of best fit on plot

# %%
x_test = list(range(18,65,1))
y_test = [best_m*x + best_b for x in x_test]

plt.scatter(ages,costs)
plt.plot(x_test,y_test,'k')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # The data in the plots above shows three distinct groups. What are the differences between the three groups? Does separating by group provide a better fit?

# %% [markdown]
# ### First, check for a gender disparity

# %%
female_ages, female_costs, female_dict = pull_ac_data(insurance_dict,"sex","female")
male_ages, male_costs, male_dict = pull_ac_data(insurance_dict,"sex","male")

plt.scatter(female_ages,female_costs, color = "pink", label = "female")
plt.scatter(male_ages,male_costs, color = "blue", label = "male")
plt.legend()
plt.show()

# %% [markdown]
# ## Data is still in three distinct groups without a clear difference between male and female. Another factor must be separating them, but there may still be a difference in male vs female groups.

# %%
male_average_cost = sum(male_costs)/len(male_costs)
female_average_cost = sum(female_costs)/len(female_costs)
overall_average_cost = sum(costs)/len(costs)

cost_avg_dict = {"overall_average":overall_average_cost,"male":male_average_cost, "female":female_average_cost}
print(cost_avg_dict)
# Out:
# {'overall_average': 13270.422265141257, 'male': 13956.751177721886, 'female': 12569.57884383534}

# %% [markdown]
# ## Next, investigate smoker vs nonsmoker

# %%
smoker_ages, smoker_costs, smoker_dict = pull_ac_data(insurance_dict,"smoker","yes")
nonsmoker_ages, nonsmoker_costs, nonsmoker_dict = pull_ac_data(insurance_dict,"smoker","no")

plt.scatter(smoker_ages,smoker_costs, color = 'blue', label = "smoker")
plt.scatter(nonsmoker_ages,nonsmoker_costs, color = 'orange', label = "non-smoker")
plt.legend()
plt.show()

# %% [markdown]
# ## There is a much bigger difference. Now, will find the linear fit for both datasets to compare.

# %%
best_sm_m, best_sm_b, smallest_sm_error = linear_reg_model_ac(smoker_ages,smoker_costs, 0, 1000, 5, 5000,50000,10)

regression_model_dict["smoker"] = {"m":best_sm_m, "b":best_sm_b, "smallest_error_":smallest_sm_error}

# %%
best_nsm_m, best_nsm_b, smallest_nsm_error = linear_reg_model_ac(nonsmoker_ages,nonsmoker_costs, 0,2000,5,0,10000,10)

regression_model_dict["nonsmoker"] = {"m":best_nsm_m, "b":best_nsm_b, "smallest_error_":smallest_nsm_error}

print(regression_model_dict)
# Out:
# {'age': {'m': 205, 'b': 0, 'smallest_error': 9328633.482559014}, 'smoker': {'m': 315, 'b': 25620, 'smallest_error_': 2656217.838379998}, 'nonsmoker': {'m': 190, 'b': 0, 'smallest_error_': 2631268.414619}}

# %%
y_testsm = [best_sm_m*x + best_sm_b for x in x_test]
y_testnsm = [best_nsm_m*x + best_nsm_b for x in x_test]

plt.scatter(smoker_ages,smoker_costs, color = 'blue', label = "smoker")
plt.plot(x_test,y_testsm,'k', label = "smoker fit")
plt.scatter(nonsmoker_ages,nonsmoker_costs, color = 'orange', label = "non-smoker")
plt.plot(x_test,y_testnsm, color = "red", label = "non-smoker fit")
plt.legend()
plt.show()

# %%
smoker_average_cost = sum(smoker_costs)/len(smoker_costs)
nonsmoker_average_cost = sum(nonsmoker_costs)/len(nonsmoker_costs)

cost_avg_dict["smoker"] = smoker_average_cost
cost_avg_dict["nonsmoker"] = nonsmoker_average_cost
print(cost_avg_dict)
# Out:
# {'overall_average': 13270.422265141257, 'male': 13956.751177721886, 'female': 12569.57884383534, 'smoker': 32050.23183153285, 'nonsmoker': 8434.268297856199}

# %% [markdown]
# ## Now will check the impact of region

# %%
northeast_ages,northeast_costs,northeast_dict = pull_ac_data(insurance_dict,"region","northeast")
northwest_ages,northwest_costs,nortwest_dict = pull_ac_data(insurance_dict,"region","northwest")
southeast_ages,southeast_costs,southeast_dict = pull_ac_data(insurance_dict,"region","southeast")
southwest_ages,southwest_costs,southwest_dict = pull_ac_data(insurance_dict,"region","southwest")

plt.scatter(northeast_ages,northeast_costs, color = 'blue', label = "northeast")
plt.scatter(northwest_ages,northwest_costs, color = 'orange', label = "northwest")
plt.scatter(southeast_ages,southeast_costs, color = 'purple', label = "southeast")
plt.scatter(southwest_ages,southwest_costs, color = 'cyan', label = "northwest")
plt.legend()
plt.show()

# %% [markdown]
# ## Not too different. Check the averages!

# %%
northeast_average_cost = sum(northeast_costs)/len(northeast_costs)
northwest_average_cost = sum(northwest_costs)/len(northwest_costs)
southeast_average_cost = sum(southeast_costs)/len(southeast_costs)
southwest_average_cost = sum(southwest_costs)/len(southwest_costs)

cost_avg_dict["northeast"] = northeast_average_cost
cost_avg_dict["northwest"] = northwest_average_cost
cost_avg_dict["southeast"] = southeast_average_cost
cost_avg_dict["southwest"] = southwest_average_cost
print(cost_avg_dict)
# Out:
# {'overall_average': 13270.422265141257, 'male': 13956.751177721886, 'female': 12569.57884383534, 'smoker': 32050.23183153285, 'nonsmoker': 8434.268297856199, 'northeast': 13406.3845163858, 'northwest': 12417.575373969228, 'southeast': 14735.411437609895, 'southwest': 12346.93737729231}

# %% [markdown]
# # Based on analysis up to this point, males, smokers, and southeasterners have the highest average costs, with smokers having the biggest differential from nonsmokers.

# %% [markdown]
# ## Why is this? Do more males smoke? Do more smokers live in the southeast than other regions?

# %% [markdown]
# ### Compare the averages of male smokers to female nonsmokers

# %%
male_smokers_ages, male_smokers_costs, male_smoker_dict = pull_ac_data(male_dict,"smoker","yes")
female_nonsmokers_ages, female_nonsmokers_costs, female_nonsmokers_dict = pull_ac_data(female_dict,"smoker","no")

print(male_smokers_ages)

plt.scatter(male_smokers_ages,male_smokers_costs, color = "gray", label = "male smokers")
plt.scatter(female_nonsmokers_ages,female_nonsmokers_costs, color = "blue", label = "female nonsmokers")
plt.legend()
plt.show()

male_sm_average_cost = sum(male_smokers_costs)/len(male_smokers_costs)
female_nsm_average_cost = sum(female_nonsmokers_costs)/len(female_nonsmokers_costs)
cost_avg_dict["male_smoker"] = male_sm_average_cost
cost_avg_dict["female_nonsmoker"] = female_nsm_average_cost
print(cost_avg_dict)
# Out:
# [27.0, 30.0, 31.0, 22.0, 28.0, 35.0, 60.0, 36.0, 48.0, 36.0, 58.0, 18.0, 28.0, 22.0, 45.0, 59.0, 56.0, 38.0, 20.0, 63.0, 44.0, 34.0, 30.0, 46.0, 48.0, 18.0, 30.0, 36.0, 35.0, 19.0, 42.0, 19.0, 18.0, 54.0, 50.0, 56.0, 19.0, 52.0, 19.0, 46.0, 40.0, 50.0, 54.0, 25.0, 19.0, 47.0, 31.0, 43.0, 34.0, 45.0, 52.0, 50.0, 26.0, 24.0, 55.0, 64.0, 61.0, 40.0, 56.0, 42.0, 54.0, 61.0, 24.0, 21.0, 29.0, 51.0, 19.0, 39.0, 42.0, 57.0, 49.0, 48.0, 30.0, 49.0, 37.0, 18.0, 39.0, 42.0, 43.0, 62.0, 60.0, 39.0, 27.0, 41.0, 35.0, 23.0, 29.0, 27.0, 53.0, 18.0, 33.0, 30.0, 53.0, 27.0, 33.0, 56.0, 36.0, 41.0, 25.0, 32.0, 57.0, 47.0, 60.0, 18.0, 45.0, 37.0, 25.0, 51.0, 44.0, 34.0, 54.0, 43.0, 51.0, 29.0, 31.0, 30.0, 24.0, 47.0, 43.0, 47.0, 19.0, 18.0, 22.0, 20.0, 22.0, 49.0, 47.0, 59.0, 37.0, 28.0, 47.0, 38.0, 25.0, 33.0, 60.0, 19.0, 18.0, 31.0, 20.0, 36.0, 52.0, 52.0, 64.0, 32.0, 24.0, 20.0, 64.0, 24.0, 26.0, 39.0, 61.0, 20.0, 19.0, 45.0, 62.0, 43.0, 42.0, 32.0, 62.0]
# {'overall_average': 13270.422265141257, 'male': 13956.751177721886, 'female': 12569.57884383534, 'smoker': 32050.23183153285, 'nonsmoker': 8434.268297856199, 'northeast': 13406.3845163858, 'northwest': 12417.575373969228, 'southeast': 14735.411437609895, 'southwest': 12346.93737729231, 'male_smoker': 33042.00597528302, 'female_nonsmoker': 8762.297299541116}

# %% [markdown]
# ### Male smokers are above the average of smokers alone, while female nonsmokers have a higher average than nonsmokers alone. Check region - male SE smokers vs female SW nonsmokers

# %%
male_se_smokers_ages, male_se_smokers_costs, male_se_smoker_dict = pull_ac_data(male_smoker_dict,"region","southeast")
female_sw_nonsmokers_ages, female_sw_nonsmokers_costs, female_sw_nonsmokers_dict = pull_ac_data(female_nonsmokers_dict,"region","southwest")

plt.scatter(male_se_smokers_ages,male_se_smokers_costs, color = "gray", label = "male SE smokers")
plt.scatter(female_sw_nonsmokers_ages,female_sw_nonsmokers_costs, color = "blue", label = "female SW nonsmokers")
plt.legend()
plt.show()

male_se_sm_average_cost = sum(male_se_smokers_costs)/len(male_se_smokers_costs)
female_sw_nsm_average_cost = sum(female_sw_nonsmokers_costs)/len(female_sw_nonsmokers_costs)
cost_avg_dict["male_se_smoker"] = male_se_sm_average_cost
cost_avg_dict["female_sw_nonsmoker"] = female_sw_nsm_average_cost
print(cost_avg_dict)
# Out:
# {'overall_average': 13270.422265141257, 'male': 13956.751177721886, 'female': 12569.57884383534, 'smoker': 32050.23183153285, 'nonsmoker': 8434.268297856199, 'northeast': 13406.3845163858, 'northwest': 12417.575373969228, 'southeast': 14735.411437609895, 'southwest': 12346.93737729231, 'male_smoker': 33042.00597528302, 'female_nonsmoker': 8762.297299541116, 'male_se_smoker': 36029.83936654546, 'female_sw_nonsmoker': 8234.091260141842}

# %% [markdown]
# ## The average cost for a male who smokes and lives in the southeast is higher than just a male smoker and just a smoker, and the female southwest nonsmoker average cost is lower than just a nonsmoker. Try to find a way to predict cost below

# %% [markdown]
# # Parameter Estimation: sex, smoker, region
#
# ## m is a product of some combination of those parameters
# ### y = mx + b or yhat = [beta1, beta2, beta3]*X

# %%
beta1ests = [b1 for b1 in range(0,100,1)]
beta2ests = [b2 for b2 in range(0,100,1)]
beta3ests = [b3 for b3 in range(0,100,1)]
